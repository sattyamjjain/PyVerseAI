# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

from src.load_data import load_products

# %%
products = load_products()

# %% [markdown]
# ### product descriptions

# %%
n = 5
for _, row in products.head(n).iterrows():
    display(Markdown(f"**{row['name']}**\n\n{row['description']}\n\n_Category: {row['category']}_\n\n"))
# Out:
# **DU Vario-Anschluss-Set für WC mit Universal-Abgang, inkl. Excenter**
#
# Duravit Standardartikel Ablaufgarnituren Anschluss-Set
#
# _Category: Badzubehör & Accessoires_
# **DU Ablaufbogen mit Rosette Abgang waagrecht, weiß**
#
# Duravit Ablaufbogen, Durchmesser Zulauf: 130 mm, Durchmesser Ablauf: 110 mm
#
# _Category: Badzubehör & Accessoires_
# **DU Ablaufstutzen mit Rosette Abgang waagrecht, weiß**
#
# Duravit Ablaufstutzen
#
# _Category: Badzubehör & Accessoires_
# **DU Me by Starck WC-Sitz o. Absenk. Weiß**
#
# Duravit ME by Starck WC-Sitz, Weiß Hochglanz, Absenkautomatik: Nein, Material Scharnier: Edelstahl, Farbe Scharnier: Edelstahl, Überlappend
#
# _Category: WC-Sitze_
# **DU Me by Starck WC-Sitz o.Absenk. Weiß/Weiß Seidenmatt**
#
# Duravit ME by Starck WC-Sitz, Weiß Seidenmatt, Absenkautomatik: Nein, Material Scharnier: Edelstahl, Farbe Scharnier: Edelstahl, Überlappend
#
# _Category: WC-Sitze_

# %% [markdown]
# ### product categories

# %%
category_counts = products['category'].value_counts()

plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar')
plt.title('Number of Products per Category')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
